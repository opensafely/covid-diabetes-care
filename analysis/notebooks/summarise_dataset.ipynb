# %%
# %load_ext autoreload
# %autoreload 2
import lib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for x in [2019, 2020, 2021, 2022, 2023]:
    lib.make_tables(x)
# Out:
# <h1>2019</h1>
# <h3>Population totals</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>diabetes</th>
#       <th>No diabetes</th>
#       <th>t1dm</th>
#       <th>t2dm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total</th>
#       <th>-</th>
#       <td>390</td>
#       <td>80</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">diabetes</th>
#       <th>No diabetes</th>
#       <td>390</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>t1dm</th>
#       <td>0</td>
#       <td>80</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>t2dm</th>
#       <td>0</td>
#       <td>0</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">hba1c_cat</th>
#       <th>&lt;=58</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>58-86</th>
#       <td>0</td>
# ...
